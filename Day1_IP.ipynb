# %%
# pip install opencv-python
# cv2 -> Computer Vision
import cv2

# %%
img=cv2.imread("image3.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# (height, width, colour channel RGB)
# if black and white then there is no colour channel
# Out:
# (1080, 1920, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img) # opencv - >BGR

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
cv2.imshow("Nature",img) # Rabbit -> window name
while True:
    key =cv2.waitKey(10)& 0xFF 
    if(key==27):  # 27-> ASCII of Esc
        break
        #0 - infinitely waiting
cv2.destroyAllWindows()
